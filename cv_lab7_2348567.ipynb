# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha-rrr/2348567/blob/main/cv_lab7_2348567.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# To read the image

# %%
original_image = cv2.imread('/content/parrot.jpeg')

# %% [markdown]
# including the noise to the image:

# %%
def add_noise(image, mean=0, std=25):
    row, col, ch = image.shape
    gauss = np.random.normal(mean, std, (row, col, ch))
    gauss = gauss.reshape(row, col, ch)
    noisy_image = image + gauss
    return noisy_image.astype(np.uint8)

noisy_image = add_noise(original_image)

# %% [markdown]
# Displaying the noise image and the original image

# %%
# Display the original and noisy images
cv2_imshow( original_image)
cv2_imshow( noisy_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=367x600>
# <PIL.Image.Image image mode=RGB size=367x600>

# %%
# Apply Gaussian blur filter to remove Gaussian noise
denoised_gaussian = cv2.GaussianBlur(noisy_image, (5, 5), 0)

# Apply Median filter to remove salt-and-pepper noise
denoised_median = cv2.medianBlur(noisy_image, 5)

cv2_imshow( original_image)
cv2_imshow( noisy_image)
cv2_imshow( denoised_gaussian)
cv2_imshow( denoised_median)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=367x600>
# <PIL.Image.Image image mode=RGB size=367x600>
# <PIL.Image.Image image mode=RGB size=367x600>
# <PIL.Image.Image image mode=RGB size=367x600>
